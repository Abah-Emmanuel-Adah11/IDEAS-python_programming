# %% [markdown]
# # Problem Definition
# #### This project aims to predict the prices of houses in Nigeria using machine learning on features like title, town, state and packing space

# %%
import pandas as pd

# %%
data = pd.read_csv("nigeria_houses_data.csv")
data
# Out:
#        bedrooms  bathrooms  toilets  parking_space                 title  \
# 0             6          5        5              4       Detached Duplex
# 1             4          5        5              4     Terraced Duplexes
# 2             4          5        5              4       Detached Duplex
# 3             4          4        5              6       Detached Duplex
# 4             4          4        5              2  Semi Detached Duplex
# ...         ...        ...      ...            ...                   ...
# 24321         2          2        2              4        Block of Flats
# 24322         4          5        5              4        Block of Flats
# 24323         4          5        5              4       Detached Duplex
# 24324         3          4        4              3        Block of Flats
# 24325         4          5        5              4       Detached Duplex
#
#                        town  state        price
# ...

# %%
data.isna().sum()
# Out:
# bedrooms         0
# bathrooms        0
# toilets          0
# parking_space    0
# title            1
# town             1
# state            1
# price            8
# dtype: int64
